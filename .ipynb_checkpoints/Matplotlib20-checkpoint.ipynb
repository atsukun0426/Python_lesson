# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
x = np.arange(10)
y = np.random.randint(-10, 10, 10)

# %%
plt.plot(x, y)

# %%
x1 = np.random.randint(10, 20, 10)
x2 = np.random.randint(20, 30, 20)
y2 = np.ramdom.randint(0, 40, 20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e5c21292bc04> in <module>
#       1 x1 = np.random.randint(10, 20, 10)
#       2 x2 = np.random.randint(20, 30, 20)
# ----> 3 y1 = np.ramdom.randint(50, 100, 20)
#       4 y2 = np.ramdom.randint(0, 40, 20)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/__init__.py in __getattr__(attr)
#     301                 return Tester
#     302
# --> 303             raise AttributeError("module {!r} has no attribute "
#     304                                  "{!r}".format(__name__, attr))
#     305
#
# AttributeError: module 'numpy' has no attribute 'ramdom'
