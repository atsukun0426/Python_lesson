# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
x = np.arange(10)
y = np.random.randint(-10, 10, 10)

# %%
plt.plot(x, y)

# %%
x1 = np.random.randint(10, 20, 20)
x2 = np.random.randint(20, 30, 20)
y1 = np.random.randint(50, 100, 20)
y2 = np.random.randint(0, 40, 20)

# %%
plt.scatter(x1, y1)
plt.scatter(x2, y2)

# %%
data = np.random.randint(0, 10, 10)

# %%
plt.hist(data)
# Out:
# (array([1., 0., 2., 0., 1., 3., 0., 0., 2., 1.]),
#  array([2. , 2.7, 3.4, 4.1, 4.8, 5.5, 6.2, 6.9, 7.6, 8.3, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, bins=15)
# Out:
# (array([1., 0., 0., 0., 2., 0., 1., 0., 3., 0., 0., 0., 2., 0., 1.]),
#  array([2.        , 2.46666667, 2.93333333, 3.4       , 3.86666667,
#         4.33333333, 4.8       , 5.26666667, 5.73333333, 6.2       ,
#         6.66666667, 7.13333333, 7.6       , 8.06666667, 8.53333333,
#         9.        ]),
#  <BarContainer object of 15 artists>)
